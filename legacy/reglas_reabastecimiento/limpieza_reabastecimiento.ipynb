# %%
import pandas as pd

# %%
def load_data(file_path):
    """Load data from a CSV file into a pandas DataFrame."""
    return pd.read_csv(file_path)

# %%
productos = load_data('productos.csv')
reglas = load_data('reglas.csv')

# %%
# Mostrar las columnas de cada DataFrame
print('Columnas de productos.csv:')
print(productos.columns.tolist())
print('\nColumnas de reglas.csv:')
print(reglas.columns.tolist())
# Out:
# Columnas de productos.csv:
# ['Cantidad a la mano', 'Cantidad pronosticada', 'Coste', 'Decoración de la actividad de excepción', 'Etiquetas', 'Favorito', 'Marca', 'Nombre', 'Precio de venta', 'Precio de venta con impuestos', 'Precio Tarifa', 'Referencia interna', 'Unidad de medida', 'Es un kit']
#
# Columnas de reglas.csv:
# ['id', 'product_max_qty', 'product_min_qty', 'qty_to_order', 'product_id', 'reviewed', 'route_id', 'location_id']

# %%
# Imprimir la columna 'product_id' de reglas
print(reglas['product_id'])
# Out:
# 0               [C 2585] FIAT PALIO Y SIENA(NAFT,DIES,T
# 1     [TBC993] FILTRO COMBUSTIBLE TURBO (P550550)(04...
# 2                  [hgk743] KIA HGK743 MARCA: CHEVROLET
# 3               [PSL475] FILTRO DE ACEITE TECFIL PSL475
# 4     [SPRAYGRAPID] MOLYKOTE PASTA G RAPID SPRAY X27...
# 5                [107396] YPF ELAION MOTO 4T 20W50 - 1L
# 6                   [XCEL45-160] STEERING CONTROL UNITS
# 7         [AH8742] FILTRO DE AIRE FLEETGUARD (01403550)
# 8     [VP1716] FILTRO AIRE 1° DARMET (901046)(731841...
# 9           [710468/F] FILTRO AIRE 2° (SA17251)(710468)
# 10                [810300000529] CASTROL GTX 20W50 - 4L
# 11    [7T00D004007] CILINDRO DE GAS DE TORRE 7T00D00...
# 12    [BSC007102500] CILINDRO DE GAS DE MANDO HIDRAU...
# 13    [4202108] PUMA HYDRAULIC AW ISO 68 - 20L (L60267)
# 14                   [290032] SOPORTE DE MOTOR (290032)
# 15             [2292241] FRILTRO DE COMBUSTIBLE 2292241
# 16    [PS9451] Focus1.8Lmot.Dutarorq(Style,Ghia,Tren...
# 17      [01.1.50.20] GULF GEARTEK HD 150 - 20L (L60057)
# 18                             [RK16] FILTRO RAMA RK 16
# 19          [3640] DOPPELKUPPLUNGS GETRIEBE-OL DSG 8100
# 20         [02234133] RETEN DELANTERO (GRANDE) CIGUEÑAL
# 21    [810300000522] CASTROL GO! 2T ONE SHOT 32 - 10...
# 22    [MN9829-025] MANNOL CERAMO ESTER X250ML ADITIV...
# 23           [33338722] ACEITE TEXACO RANDO HD 46 - 20L
# 24                                     [32/925364] CLIP
# 25    [FAP7007] FILTRO DE AIRE WEGA VW FAP7007 (C229...
# 26           [01.1.13.20] GULF MAX 15W40 - 20L (L60957)
# 27    [98553895] ACDELCO 0W20 API SN/RC DEXOS1 GEN3 ...
# 28    [P558000] FILTRO SEPARADOR DE AGUA DONALDSON P...
# 29    [1581] LIQUI MOLY MOTORBIKE 1581 4T BIKE-ADDIT...
# 30       [CA10261] FILTRO DE AIRE Dodge RAM 2500 (alto)
# 31     [107796] YPF ELAION MOTO 4T SINTETICO 10W50 - 1L
# Name: product_id, dtype: object

# %%
# Extraer lo que está entre corchetes en cada 'product_id' y verificar cantidad
import re
product_ids = reglas['product_id'].astype(str)
extraidos = product_ids.str.extract(r'\[(.*?)\]')[0]
print('Extraídos:', extraidos.tolist())
print('Cantidad de elementos extraídos:', extraidos.count())
if extraidos.count() == 32:
    print('Hay 32 elementos extraídos correctamente.')
else:
    print(f'Atención: se extrajeron {extraidos.count()} elementos, no 32.')
# Out:
# Extraídos: ['C 2585', 'TBC993', 'hgk743', 'PSL475', 'SPRAYGRAPID', '107396', 'XCEL45-160', 'AH8742', 'VP1716', '710468/F', '810300000529', '7T00D004007', 'BSC007102500', '4202108', '290032', '2292241', 'PS9451', '01.1.50.20', 'RK16', '3640', '02234133', '810300000522', 'MN9829-025', '33338722', '32/925364', 'FAP7007', '01.1.13.20', '98553895', 'P558000', '1581', 'CA10261', '107796']
# Cantidad de elementos extraídos: 32
# Hay 32 elementos extraídos correctamente.

# %%
# Contar cuántas veces cada valor extraído aparece exactamente en 'Referencia interna' de productos
conteos = {}
for val in extraidos.dropna():
    conteos[val] = (productos['Referencia interna'].astype(str) == val).sum()
print('Conteos de coincidencias exactas en Referencia interna:')
for k, v in conteos.items():
    print(f"{k}: {v}")
# Out:
# Conteos de coincidencias exactas en Referencia interna:
# C 2585: 1
# TBC993: 1
# hgk743: 1
# PSL475: 1
# SPRAYGRAPID: 1
# 107396: 1
# XCEL45-160: 1
# AH8742: 1
# VP1716: 1
# 710468/F: 1
# 810300000529: 1
# 7T00D004007: 1
# BSC007102500: 1
# 4202108: 1
# 290032: 1
# 2292241: 1
# PS9451: 2
# 01.1.50.20: 1
# RK16: 1
# 3640: 2
# 02234133: 1
# 810300000522: 1
# MN9829-025: 1
# 33338722: 1
# 32/925364: 1
# FAP7007: 1
# 01.1.13.20: 1
# 98553895: 1
# P558000: 1
# 1581: 1
# CA10261: 2
# 107796: 1

# %%
# Eliminar filas específicas de productos y mostrar las eliminadas
cond1 = productos['Nombre'] == 'FILTRO DE AIRE Dodge RAM 2500 (alto)'
cond2 = (productos['Referencia interna'].astype(str) == '3640') & (productos['Precio de venta'] == 46267.2)
cond3 = productos['Nombre'] == 'Ford Focus TDCi.'
filtro_borrar = cond1 | cond2 | cond3
borrados = productos[filtro_borrar]
productos = productos[~filtro_borrar]
print('Filas eliminadas:')
print(borrados)
# Out:
# Filas eliminadas:
#        Cantidad a la mano  Cantidad pronosticada     Coste  \
# 16940                -1.0                   -1.0  32045.06
# 21970                 0.0                    0.0  22575.08
# 24879                 0.0                    0.0  30844.80
#
#        Decoración de la actividad de excepción Etiquetas Favorito       Marca  \
# 16940                                      NaN       NaN      NaN        FRAM
# 21970                                      NaN       NaN      NaN        FRAM
# 24879                                      NaN       NaN      NaN  LIQUI MOLY
#
#                                                 Nombre  Precio de venta  \
# 16940             FILTRO DE AIRE Dodge RAM 2500 (alto)         50631.19
# 21970                                 Ford Focus TDCi.         35668.63
# 24879  OPPEL KUPPLUNG ÖL DSG 8100 - doble embrague DSG         46267.20
#
#        Precio de venta con impuestos  Precio Tarifa Referencia interna  \
# 16940                       61263.74       50631.19            CA10261
# 21970                       43159.04       35668.63             PS9451
# 24879                       55983.31       46267.20               3640
#
#       Unidad de medida Es un kit
# 16940         Unidades       NaN
# 21970         Unidades       NaN
# 24879         Unidades       NaN

# %%
# Mostrar los valores distintos de la columna 'Es un kit' de productos
productos['Es un kit'].unique()
# Out:
# array([nan, True], dtype=object)

# %%
# Eliminar todas las filas donde 'Es un kit' es True y mostrar las eliminadas
kits = productos[productos['Es un kit'] == True]
productos = productos[productos['Es un kit'] != True]
print('Filas eliminadas (Es un kit = True):')
print(kits)
# Out:
# Filas eliminadas (Es un kit = True):
#        Cantidad a la mano  Cantidad pronosticada       Coste  \
# 57                   14.0                   12.0    47820.64
# 123                  64.0                   60.0    40597.97
# 127                  93.0                   93.0    49200.80
# 172                  11.0                   11.0    37775.40
# 196                   2.0                    2.0    84976.99
# 497                   3.0                    3.0   179451.07
# 22335                29.0                   29.0    37538.44
# 23096                 1.0                    1.0        0.00
# 24505                 1.0                    0.0  1143483.00
#
#        Decoración de la actividad de excepción  \
# 57                                         NaN
# 123                                        NaN
# 127                                        NaN
# 172                                        NaN
# 196                                        NaN
# 497                                        NaN
# 22335                                      NaN
# 23096                                      NaN
# 24505                                      NaN
#
#                                         Etiquetas Favorito          Marca  \
# 57                                            NaN     True           GULF
# 123                                           NaN     True           GULF
# 127                                           NaN     True           GULF
# 172                                           NaN     True           GULF
# 196                                           NaN     True           GULF
# 497                                           NaN     True  PATRIOT POWER
# 22335                                         NaN      NaN           GULF
# 23096  VOLKSWAGEN FOX / CROSSFOX / SAVEIRO 1.6 8V      NaN       DOLZ/INA
# 24505                                         NaN      NaN          CAIFA
#
#                                                   Nombre  Precio de venta  \
# 57              GULF ANTIFREEZE ORG.ROJO - 1L (CAJA 12U)         77947.64
# 123                        GULF MAX 15W40 - 4L (CAJA 4U)         66174.69
# 127                        GULF MAX 20W50 - 4L (CAJA 4U)         80197.30
# 172    GULF PRIDE 4T SPECIAL 20W50 DOY PACK - 800ML (...         61573.90
# 196                GULF ULTRASYNTH GDI 5W30 - CAJA 12X1L        138512.49
# 497                   PATRIOT POWER MT-10 8OZ (CAJA X12)        292505.24
# 22335  GULF PRIDE 4T SPECIAL 20W50 DOY PACK X1L (CAJA...         61187.66
# 23096  KIT DISTRIBUCION INA Y BOMBA DE AGUA DOLZ VW F...        100976.47
# 24505           MOTOR TRIFASICO 7.5 HP-EJE MACHO C/BRIDA       1806703.14
#
#        Precio de venta con impuestos  Precio Tarifa    Referencia interna  \
# 57                          94316.64       77947.64           01.5.31.41C
# 123                         80071.37       66174.69           01.1.13.42C
# 127                         97038.73       80197.30           01.1.15.42C
# 172                         74504.42       61573.90           01.4.12.56C
# 196                        167600.11      138512.49          01.0.28.41/C
# 497                        353931.34      292505.24                  005C
# 22335                       74037.07       61187.66           01.4.12.55C
# 23096                      122181.53      100976.47     A179+5300697100A1
# 24505                     2186110.80     1806703.14  RVA050-10-59IN-MOTOR
#
#       Unidad de medida Es un kit
# 57            Unidades      True
# 123           Unidades      True
# 127           Unidades      True
# 172           Unidades      True
# 196           Unidades      True
# 497           Unidades      True
# 22335         Unidades      True
# 23096         Unidades      True
# 24505         Unidades      True

# %%
# Crear un DataFrame productos_limpios sin los productos que son kit
productos_limpios = productos[productos['Es un kit'] != True].copy()
productos_limpios
# Out:
#        Cantidad a la mano  Cantidad pronosticada      Coste  \
# 0                     0.0                    0.0   94981.95
# 1                     0.0                    0.0  157995.17
# 2                     1.0                    1.0  955421.89
# 3                     0.0                    0.0   25726.50
# 4                     0.0                    0.0  883879.88
# ...                   ...                    ...        ...
# 28786                 0.0                    0.0   42162.75
# 28787                 0.0                    0.0       0.00
# 28788                 0.0                    0.0       4.80
# 28789                 0.0                    0.0   82644.63
# 28790                 0.0                    0.0   96255.25
#
#        Decoración de la actividad de excepción Etiquetas Favorito  \
# 0                                          NaN       NaN     True
# 1                                          NaN       NaN     True
# 2                                          NaN       NaN     True
# 3                                          NaN       NaN     True
# 4                                          NaN       NaN     True
# ...                                        ...       ...      ...
# 28786                                      NaN       NaN      NaN
# 28787                                      NaN       NaN      NaN
# 28788                                      NaN       NaN      NaN
# 28789                                      NaN       NaN      NaN
# 28790                                      NaN       NaN      NaN
#
#                 Marca                                        Nombre  \
# 0              TEXACO                 ACEITE TEXACO ARIES 100 - 20L
# 1              TEXACO      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 1L
# 2              TEXACO    ACEITE TEXACO HAVOLINE PRODS M 5W30 - 200L
# 3              TEXACO      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 4L
# 4              TEXACO     ACEITE TEXACO MULTIGEAR EP-5 80W90 - 200L
# ...               ...                                           ...
# 28786             NaN                          ÁCIDO FÓRMICO - 35KG
# 28787        GENERICO                   ÁCIDO SULFÚRICO AL 29% x LT
# 28788  CENTAURO ALPHA      ÁCIDO TOLUENO SULFÓNICO MONOHIDRATO - KG
# 28789        GENERICO  ÓVULOS/VALVULAS REFRIGERACIÓN PARA AUTOMOTOR
# 28790         LONKING                ÚLTIMO DER. 16Y8100003 LONKING
#
#        Precio de venta  Precio de venta con impuestos  Precio Tarifa  \
# 0            151971.12                      183885.06      151971.12
# 1            257532.13                      311613.88      257532.13
# 2           1433132.84                     1734090.74     1433132.84
# 3             41934.20                       50740.38       41934.20
# 4           1325819.82                     1604241.98     1325819.82
# ...                ...                            ...            ...
# 28786            47.25                          57.17       64094.63
# 28787          8976.00                       10860.96        8976.00
# 28788             7.10                           8.59           7.10
# 28789        130578.52                      158000.01      130578.52
# 28790        152083.30                      184020.79      152083.30
#
#       Referencia interna Unidad de medida Es un kit
# 0               33337022         Unidades       NaN
# 1               31081353         Unidades       NaN
# 2               31081310         Unidades       NaN
# 3               31081365         Unidades       NaN
# 4               32055210         Unidades       NaN
# ...                  ...              ...       ...
# 28786       ACIDOFORMICO         Unidades       NaN
# 28787        ACSULFURICO         Unidades       NaN
# 28788         Á233452415         Unidades       NaN
# 28789             212164         Unidades       NaN
# 28790         16Y8100003         Unidades       NaN
#
# [28779 rows x 14 columns]

# %%
# Eliminar de productos_limpios todas las filas donde 'Es un kit' es True y mostrar las eliminadas
kits_limpios = productos_limpios[productos_limpios['Es un kit'] == True]
productos_limpios = productos_limpios[productos_limpios['Es un kit'] != True]
print('Filas eliminadas de productos_limpios (Es un kit = True):')
print(kits_limpios)
# Out:
# Filas eliminadas de productos_limpios (Es un kit = True):
# Empty DataFrame
# Columns: [Cantidad a la mano, Cantidad pronosticada, Coste, Decoración de la actividad de excepción, Etiquetas, Favorito, Marca, Nombre, Precio de venta, Precio de venta con impuestos, Precio Tarifa, Referencia interna, Unidad de medida, Es un kit]
# Index: []

# %%
# Eliminar de productos_limpios todas las filas cuya 'Referencia interna' esté en extraidos y mostrar las eliminadas
referencias_a_borrar = extraidos.dropna().unique()
borrados_ref = productos_limpios[productos_limpios['Referencia interna'].astype(str).isin(referencias_a_borrar)]
productos_limpios = productos_limpios[~productos_limpios['Referencia interna'].astype(str).isin(referencias_a_borrar)]
print('Filas eliminadas por Referencia interna en extraidos:')
print(borrados_ref)
# Out:
# Filas eliminadas por Referencia interna en extraidos:
#        Cantidad a la mano  Cantidad pronosticada       Coste  \
# 7                     0.0                   -1.0    61553.77
# 29                   33.0                   32.0     1374.65
# 102                   0.0                   -6.0    51500.21
# 121                  20.0                   19.0    54420.17
# 594                   5.0                    3.0    47532.98
# 777                   1.0                  -11.0     3634.88
# 779                  10.0                   10.0     4946.87
# 1066                  9.0                    9.0    43632.94
# 2996                 23.0                   22.0    25079.47
# 3178                 -4.0                   -4.0    47502.00
# 3179                 -2.0                   -2.0    51480.00
# 3224                  0.0                   -1.0    40235.00
# 4293                  0.0                    0.0    30166.56
# 4906                  0.0                   -1.0     4744.93
# 8687                  2.0                    1.0    11985.33
# 12256                 0.0                   -2.0    38194.00
# 13022                 1.0                    1.0    32045.06
# 15227                -2.0                   -2.0    21307.00
# 16107                 5.0                    5.0     6571.25
# 16989                 8.0                   -5.0    57150.60
# 17864                31.0                   24.0     4920.16
# 20868                 1.0                    0.0    34354.93
# 21187                 0.0                    0.0    22165.00
# 21575                 0.0                   -1.0    21536.96
# 21906                 0.0                   -1.0    22575.08
# 22947                 0.0                   -1.0    55794.04
# 23627                 0.0                    0.0     8990.06
# 24015                45.0                   44.0     7286.70
# 24428                16.0                   15.0    28990.00
# 25893                 0.0                   -1.0    19422.00
# 26801                 6.0                  -39.0     9820.76
# 26872                -1.0                   -1.0  2156615.00
#
#        Decoración de la actividad de excepción Etiquetas Favorito       Marca  \
# 7                                          NaN       NaN     True      TEXACO
# 29                                         NaN       NaN     True     CASTROL
# 102                                        NaN       NaN     True        GULF
# 121                                        NaN       NaN     True        GULF
# 594                                        NaN       NaN     True        PUMA
# 777                                        NaN       NaN     True         YPF
# 779                                        NaN       NaN     True         YPF
# 1066                                       NaN       NaN      NaN     ACDELCO
# 2996                                       NaN       NaN      NaN     CASTROL
# 3178                                       NaN       NaN      NaN        BULL
# 3179                                       NaN       NaN      NaN        BULL
# 3224                                       NaN       NaN      NaN         JCB
# 4293                                       NaN       NaN      NaN  LIQUI MOLY
# 4906                                       NaN       NaN      NaN        MANN
# 8687                                       NaN       NaN      NaN      DARMET
# 12256                                      NaN       NaN      NaN     FUERDUN
# 13022                                      NaN       NaN      NaN        FRAM
# 15227                                      NaN       NaN      NaN       TURBO
# 16107                                      NaN       NaN      NaN      TECFIL
# 16989                                      NaN       NaN      NaN  FLEETGUARD
# 17864                                      NaN       NaN      NaN        WEGA
# 20868                                      NaN       NaN      NaN        RAMA
# 21187                                      NaN       NaN      NaN   DONALDSON
# 21575                                      NaN       NaN      NaN       IVECO
# 21906                                      NaN       NaN      NaN        FRAM
# 22947                                      NaN       NaN      NaN     BALDWIN
# 23627                                      NaN       NaN      NaN  LIQUI MOLY
# 24015                                      NaN       NaN      NaN      MANNOL
# 24428                                      NaN       NaN      NaN    MOLYKOTE
# 25893                                      NaN       NaN      NaN       DEUTZ
# 26801                                      NaN       NaN      NaN        IMET
# 26872                                      NaN       NaN      NaN       EATON
#
#                                                   Nombre  Precio de venta  \
# 7                        ACEITE TEXACO RANDO HD 46 - 20L         98486.03
# 29          CASTROL GO! 2T ONE SHOT 32 - 100 ML (107922)          2061.98
# 102                   GULF GEARTEK HD 150 - 20L (L60057)         82400.34
# 121                        GULF MAX 15W40 - 20L (L60957)         87072.27
# 594              PUMA HYDRAULIC AW ISO 68 - 20L (L60267)         76052.77
# 777                        YPF ELAION MOTO 4T 20W50 - 1L          5452.32
# 779              YPF ELAION MOTO 4T SINTETICO 10W50 - 1L          7420.31
# 1066     ACDELCO 0W20 API SN/RC DEXOS1 GEN3 (F50D1) - 4L         63267.76
# 2996                              CASTROL GTX 20W50 - 4L         37619.21
# 3178    CILINDRO DE GAS DE MANDO HIDRAULICO BSC007102500         68851.59
# 3179                CILINDRO DE GAS DE TORRE 7T00D004007         74617.49
# 3224                                                CLIP            47.35
# 4293                DOPPELKUPPLUNGS GETRIEBE-OL DSG 8100         45249.84
# 4906                      FIAT PALIO Y SIENA(NAFT,DIES,T          7496.99
# 8687   FILTRO AIRE 1° DARMET (901046)(73184170)(P7725...         20451.76
# 12256                   FILTRO AIRE 2° (SA17251)(710468)            52.88
# 13022                  FILTRO AIRE DODGE RAM 2500 (ALTO)         50631.19
# 15227  FILTRO COMBUSTIBLE TURBO (P550550)(04020788)(W...            26.55
# 16107                     FILTRO DE ACEITE TECFIL PSL475         10382.58
# 16989               FILTRO DE AIRE FLEETGUARD (01403550)            72.25
# 17864  FILTRO DE AIRE WEGA VW FAP7007 (C2295/2)(19347...          7773.85
# 20868                                  FILTRO RAMA RK 16         54280.79
# 21187         FILTRO SEPARADOR DE AGUA DONALDSON P558000            27.45
# 21575                     FRILTRO DE COMBUSTIBLE 2292241         34028.40
# 21906  Focus1.8Lmot.Dutarorq(Style,Ghia,Trend,EXE)Kin...         35668.63
# 22947                        KIA HGK743 MARCA: CHEVROLET         55794.04
# 23627  LIQUI MOLY MOTORBIKE 1581 4T BIKE-ADDITIVE X12...         13485.09
# 24015    MANNOL CERAMO ESTER X250ML ADITIVO ANTIFRICCIÓN         10930.05
# 24428          MOLYKOTE PASTA G RAPID SPRAY X278G/400CM3            33.45
# 25893                  RETEN DELANTERO (GRANDE) CIGUEÑAL            22.86
# 26801                          SOPORTE DE MOTOR (290032)         15516.80
# 26872                             STEERING CONTROL UNITS          2769.30
#
#        Precio de venta con impuestos  Precio Tarifa Referencia interna  \
# 7                          119168.10       98486.03           33338722
# 29                           2495.00        2061.98       810300000522
# 102                         99704.41       82400.34         01.1.50.20
# 121                        105357.45       87072.27         01.1.13.20
# 594                         92023.85       76052.77            4202108
# 777                          6597.31        5452.32             107396
# 779                          8978.58        7420.31             107796
# 1066                        76553.99       63267.76           98553895
# 2996                        45519.24       37619.21       810300000529
# 3178                        83310.42       68851.59       BSC007102500
# 3179                        90287.16       74617.49        7T00D004007
# 3224                           57.29       64230.28          32/925364
# 4293                        54752.31       45249.84               3640
# 4906                         9071.36        7496.99             C 2585
# 8687                        24746.63       20451.76             VP1716
# 12256                          63.98       71731.72           710468/F
# 13022                       61263.74       50631.19            CA10261
# 15227                          32.13       36015.08             TBC993
# 16107                       12562.92       10382.58             PSL475
# 16989                          87.42       98007.13             AH8742
# 17864                        9406.36        7773.85            FAP7007
# 20868                       65679.76       54280.79               RK16
# 21187                          33.21       37235.93            P558000
# 21575                       41174.36       34028.40            2292241
# 21906                       43159.04       35668.63             PS9451
# 22947                       67510.79       55794.04             hgk743
# 23627                       16316.96       13485.09               1581
# 24015                       13225.36       10930.05         MN9829-025
# 24428                          40.47       45374.93        SPRAYGRAPID
# 25893                          27.66       31009.59           02234133
# 26801                       18775.33       15516.80             290032
# 26872                        3350.85     3756555.45         XCEL45-160
#
#       Unidad de medida Es un kit
# 7             Unidades       NaN
# 29            Unidades       NaN
# 102           Unidades       NaN
# 121           Unidades       NaN
# 594           Unidades       NaN
# 777           Unidades       NaN
# 779           Unidades       NaN
# 1066          Unidades       NaN
# 2996          Unidades       NaN
# 3178          Unidades       NaN
# 3179          Unidades       NaN
# 3224          Unidades       NaN
# 4293          Unidades       NaN
# 4906          Unidades       NaN
# 8687          Unidades       NaN
# 12256         Unidades       NaN
# 13022         Unidades       NaN
# 15227         Unidades       NaN
# 16107         Unidades       NaN
# 16989         Unidades       NaN
# 17864         Unidades       NaN
# 20868         Unidades       NaN
# 21187         Unidades       NaN
# 21575         Unidades       NaN
# 21906         Unidades       NaN
# 22947         Unidades       NaN
# 23627         Unidades       NaN
# 24015         Unidades       NaN
# 24428         Unidades       NaN
# 25893         Unidades       NaN
# 26801         Unidades       NaN
# 26872         Unidades       NaN

# %%
borrados_ref.shape
# Out:
# (32, 14)

# %%
# Mostrar las filas de productos_limpios con 'Referencia interna' duplicada o más
duplicados = productos_limpios[productos_limpios.duplicated('Referencia interna', keep=False)]
duplicados
# Out:
#        Cantidad a la mano  Cantidad pronosticada      Coste  \
# 8                     0.0                    0.0  223110.00
# 186                   0.0                    0.0  303027.99
# 209                   0.0                    0.0  303027.99
# 248                  13.0                   13.0   19389.24
# 368                   0.0                    0.0       0.00
# ...                   ...                    ...        ...
# 28776                 0.0                    0.0       0.00
# 28777                 0.0                    0.0       0.00
# 28778                 0.0                    0.0       0.00
# 28780                 0.0                    0.0       0.00
# 28782                 0.0                    0.0       0.00
#
#        Decoración de la actividad de excepción Etiquetas Favorito       Marca  \
# 8                                          NaN       NaN     True       SHELL
# 186                                        NaN       NaN     True        GULF
# 209                                        NaN       NaN     True        GULF
# 248                                        NaN       NaN     True  LIQUI MOLY
# 368                                        NaN       NaN     True       MOBIL
# ...                                        ...       ...      ...         ...
# 28776                                      NaN       NaN      NaN         NaN
# 28777                                      NaN       NaN      NaN         NaN
# 28778                                      NaN       NaN      NaN         NaN
# 28780                                      NaN       NaN      NaN         NaN
# 28782                                      NaN       NaN      NaN         NaN
#
#                                                   Nombre  Precio de venta  \
# 8                               AEROSHELL GREASE 5 - 3KG        264036.18
# 186    GULF SUPERFLEET SYNTH XLE 10W40 - 200L DISCONT...        454541.99
# 209    GULF SUPERFLEET SYNTH XLE 10W40 - 205L DISCONT...        454541.99
# 248                    LIQUI MOLY TOP TEC 4100 5W40 - 1L         29083.86
# 368    MOBIL ATF D/M - 200L (ROTO) Le faltan 5 litros...       1227253.35
# ...                                                  ...              ...
# 28776                                                 sd             1.00
# 28777                                  servicios de agru             1.00
# 28778                                    servicios de in             1.00
# 28780                                           sylikote             1.00
# 28782                                              zerec             0.00
#
#        Precio de venta con impuestos  Precio Tarifa Referencia interna  \
# 8                          319483.78      264036.18         A624262221
# 186                        549995.81      454541.99         01.0.27.83
# 209                        549995.81      454541.99         01.0.27.83
# 248                         35191.47       29083.86               9510
# 368                       1484976.55     1227253.35                NaN
# ...                              ...            ...                ...
# 28776                           1.21           1.00                NaN
# 28777                           1.21           1.00                NaN
# 28778                           1.21           1.00                NaN
# 28780                           1.21           1.00                NaN
# 28782                           0.00           0.00                NaN
#
#       Unidad de medida Es un kit
# 8             Unidades       NaN
# 186           Unidades       NaN
# 209           Unidades       NaN
# 248           Unidades       NaN
# 368           Unidades       NaN
# ...                ...       ...
# 28776         Unidades       NaN
# 28777         Unidades       NaN
# 28778         Unidades       NaN
# 28780         Unidades       NaN
# 28782         Unidades       NaN
#
# [7039 rows x 14 columns]

# %%
# Exportar los duplicados como CSV
duplicados.to_csv('duplicados.csv', index=False)
print('Archivo duplicados.csv guardado.')
# Out:
# Archivo duplicados.csv guardado.

# %%
# Eliminar completamente de productos_limpios todas las referencias internas que estén duplicadas
duplicadas = productos_limpios['Referencia interna'][productos_limpios['Referencia interna'].duplicated(keep=False)]
productos_sin_duplicados = productos_limpios[~productos_limpios['Referencia interna'].isin(duplicadas)]
print('Productos sin ninguna referencia interna duplicada:')
productos_sin_duplicados
# Out:
# Productos sin ninguna referencia interna duplicada:
#        Cantidad a la mano  Cantidad pronosticada      Coste  \
# 0                     0.0                    0.0   94981.95
# 1                     0.0                    0.0  157995.17
# 2                     1.0                    1.0  955421.89
# 3                     0.0                    0.0   25726.50
# 4                     0.0                    0.0  883879.88
# ...                   ...                    ...        ...
# 28786                 0.0                    0.0   42162.75
# 28787                 0.0                    0.0       0.00
# 28788                 0.0                    0.0       4.80
# 28789                 0.0                    0.0   82644.63
# 28790                 0.0                    0.0   96255.25
#
#        Decoración de la actividad de excepción Etiquetas Favorito  \
# 0                                          NaN       NaN     True
# 1                                          NaN       NaN     True
# 2                                          NaN       NaN     True
# 3                                          NaN       NaN     True
# 4                                          NaN       NaN     True
# ...                                        ...       ...      ...
# 28786                                      NaN       NaN      NaN
# 28787                                      NaN       NaN      NaN
# 28788                                      NaN       NaN      NaN
# 28789                                      NaN       NaN      NaN
# 28790                                      NaN       NaN      NaN
#
#                 Marca                                        Nombre  \
# 0              TEXACO                 ACEITE TEXACO ARIES 100 - 20L
# 1              TEXACO      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 1L
# 2              TEXACO    ACEITE TEXACO HAVOLINE PRODS M 5W30 - 200L
# 3              TEXACO      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 4L
# 4              TEXACO     ACEITE TEXACO MULTIGEAR EP-5 80W90 - 200L
# ...               ...                                           ...
# 28786             NaN                          ÁCIDO FÓRMICO - 35KG
# 28787        GENERICO                   ÁCIDO SULFÚRICO AL 29% x LT
# 28788  CENTAURO ALPHA      ÁCIDO TOLUENO SULFÓNICO MONOHIDRATO - KG
# 28789        GENERICO  ÓVULOS/VALVULAS REFRIGERACIÓN PARA AUTOMOTOR
# 28790         LONKING                ÚLTIMO DER. 16Y8100003 LONKING
#
#        Precio de venta  Precio de venta con impuestos  Precio Tarifa  \
# 0            151971.12                      183885.06      151971.12
# 1            257532.13                      311613.88      257532.13
# 2           1433132.84                     1734090.74     1433132.84
# 3             41934.20                       50740.38       41934.20
# 4           1325819.82                     1604241.98     1325819.82
# ...                ...                            ...            ...
# 28786            47.25                          57.17       64094.63
# 28787          8976.00                       10860.96        8976.00
# 28788             7.10                           8.59           7.10
# 28789        130578.52                      158000.01      130578.52
# 28790        152083.30                      184020.79      152083.30
#
#       Referencia interna Unidad de medida Es un kit
# 0               33337022         Unidades       NaN
# 1               31081353         Unidades       NaN
# 2               31081310         Unidades       NaN
# 3               31081365         Unidades       NaN
# 4               32055210         Unidades       NaN
# ...                  ...              ...       ...
# 28786       ACIDOFORMICO         Unidades       NaN
# 28787        ACSULFURICO         Unidades       NaN
# 28788         Á233452415         Unidades       NaN
# 28789             212164         Unidades       NaN
# 28790         16Y8100003         Unidades       NaN
#
# [21708 rows x 14 columns]

# %%
# Chequeos finales sobre productos_sin_duplicados
print('¿Hay kits?', productos_sin_duplicados['Es un kit'].eq(True).any())
print('¿Hay duplicados?', productos_sin_duplicados['Referencia interna'].duplicated().any())
print('¿Hay referencias internas en extraidos?', productos_sin_duplicados['Referencia interna'].astype(str).isin(extraidos.dropna().unique()).any())
# Out:
# ¿Hay kits? False
# ¿Hay duplicados? False
# ¿Hay referencias internas en extraidos? False

# %%
# Agregar columna 'product_id' con el formato '[referencia] nombre'
productos_sin_duplicados['product_id'] = '[' + productos_sin_duplicados['Referencia interna'].astype(str) + '] ' + productos_sin_duplicados['Nombre'].astype(str)
productos_sin_duplicados[['Referencia interna', 'Nombre', 'product_id']]
# Out:
# /var/folders/v5/vrmq23k56_x2v6y175jf3kbw0000gn/T/ipykernel_52405/1771724626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productos_sin_duplicados['product_id'] = '[' + productos_sin_duplicados['Referencia interna'].astype(str) + '] ' + productos_sin_duplicados['Nombre'].astype(str)
#       Referencia interna                                        Nombre  \
# 0               33337022                 ACEITE TEXACO ARIES 100 - 20L
# 1               31081353      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 1L
# 2               31081310    ACEITE TEXACO HAVOLINE PRODS M 5W30 - 200L
# 3               31081365      ACEITE TEXACO HAVOLINE PRODS M 5W30 - 4L
# 4               32055210     ACEITE TEXACO MULTIGEAR EP-5 80W90 - 200L
# ...                  ...                                           ...
# 28786       ACIDOFORMICO                          ÁCIDO FÓRMICO - 35KG
# 28787        ACSULFURICO                   ÁCIDO SULFÚRICO AL 29% x LT
# 28788         Á233452415      ÁCIDO TOLUENO SULFÓNICO MONOHIDRATO - KG
# 28789             212164  ÓVULOS/VALVULAS REFRIGERACIÓN PARA AUTOMOTOR
# 28790         16Y8100003                ÚLTIMO DER. 16Y8100003 LONKING
#
#                                               product_id
# 0               [33337022] ACEITE TEXACO ARIES 100 - 20L
# 1      [31081353] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 2      [31081310] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 3      [31081365] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 4      [32055210] ACEITE TEXACO MULTIGEAR EP-5 80W90 ...
# ...                                                  ...
# 28786                [ACIDOFORMICO] ÁCIDO FÓRMICO - 35KG
# 28787          [ACSULFURICO] ÁCIDO SULFÚRICO AL 29% x LT
# 28788  [Á233452415] ÁCIDO TOLUENO SULFÓNICO MONOHIDRA...
# 28789  [212164] ÓVULOS/VALVULAS REFRIGERACIÓN PARA AU...
# 28790        [16Y8100003] ÚLTIMO DER. 16Y8100003 LONKING
#
# [21708 rows x 3 columns]

# %%
productos_sin_duplicados['product_id']
# Out:
# 0                 [33337022] ACEITE TEXACO ARIES 100 - 20L
# 1        [31081353] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 2        [31081310] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 3        [31081365] ACEITE TEXACO HAVOLINE PRODS M 5W30...
# 4        [32055210] ACEITE TEXACO MULTIGEAR EP-5 80W90 ...
#                                ...
# 28786                  [ACIDOFORMICO] ÁCIDO FÓRMICO - 35KG
# 28787            [ACSULFURICO] ÁCIDO SULFÚRICO AL 29% x LT
# 28788    [Á233452415] ÁCIDO TOLUENO SULFÓNICO MONOHIDRA...
# 28789    [212164] ÓVULOS/VALVULAS REFRIGERACIÓN PARA AU...
# 28790          [16Y8100003] ÚLTIMO DER. 16Y8100003 LONKING
# Name: product_id, Length: 21708, dtype: object

# %%
# Crear el DataFrame 'a_exportar' con las columnas y valores requeridos
a_exportar = pd.DataFrame({
    'id': [''] * len(productos_sin_duplicados),
    'product_max_qty': [0] * len(productos_sin_duplicados),
    'product_min_qty': [0] * len(productos_sin_duplicados),
    'qty_to_order': [0] * len(productos_sin_duplicados),
    'product_id': productos_sin_duplicados['product_id'].values,
    'reviewed': [''] * len(productos_sin_duplicados),
    'route_id': ['Comprar'] * len(productos_sin_duplicados),
    'location_id': ['VLANT/Existencias'] * len(productos_sin_duplicados)
})
a_exportar.head()
# Out:
#   id  product_max_qty  product_min_qty  qty_to_order  \
# 0                   0                0             0
# 1                   0                0             0
# 2                   0                0             0
# 3                   0                0             0
# 4                   0                0             0
#
#                                           product_id reviewed route_id  \
# 0           [33337022] ACEITE TEXACO ARIES 100 - 20L           Comprar
# 1  [31081353] ACEITE TEXACO HAVOLINE PRODS M 5W30...           Comprar
# 2  [31081310] ACEITE TEXACO HAVOLINE PRODS M 5W30...           Comprar
# 3  [31081365] ACEITE TEXACO HAVOLINE PRODS M 5W30...           Comprar
# 4  [32055210] ACEITE TEXACO MULTIGEAR EP-5 80W90 ...           Comprar
#
#          location_id
# 0  VLANT/Existencias
# 1  VLANT/Existencias
# 2  VLANT/Existencias
# 3  VLANT/Existencias
# 4  VLANT/Existencias

# %%
# Exportar el DataFrame 'a_exportar' a CSV
a_exportar.to_csv('a_exportar.csv', index=False)
print('Archivo a_exportar.csv guardado.')
# Out:
# Archivo a_exportar.csv guardado.

# %%
# Comparar el formato de 'a_exportar.csv' y 'reglas.csv', ignorando la columna 'id'
a_exportar_csv = pd.read_csv('a_exportar.csv')
reglas_csv = pd.read_csv('reglas.csv')

# Eliminar columna 'id' si existe en ambos
if 'id' in a_exportar_csv.columns:
    a_exportar_csv = a_exportar_csv.drop(columns=['id'])
if 'id' in reglas_csv.columns:
    reglas_csv = reglas_csv.drop(columns=['id'])

# Comparar nombres de columnas
print('Columnas a_exportar.csv:', a_exportar_csv.columns.tolist())
print('Columnas reglas.csv:', reglas_csv.columns.tolist())

if list(a_exportar_csv.columns) == list(reglas_csv.columns):
    print('Los archivos tienen el mismo formato de columnas (excepto id).')
else:
    print('Diferencia en el formato de columnas:')
    print('a_exportar.csv:', a_exportar_csv.columns.tolist())
    print('reglas.csv:', reglas_csv.columns.tolist())
# Out:
# Columnas a_exportar.csv: ['product_max_qty', 'product_min_qty', 'qty_to_order', 'product_id', 'reviewed', 'route_id', 'location_id']
# Columnas reglas.csv: ['product_max_qty', 'product_min_qty', 'qty_to_order', 'product_id', 'reviewed', 'route_id', 'location_id']
# Los archivos tienen el mismo formato de columnas (excepto id).

# %%
# Dividir 'a_exportar.csv' en archivos de hasta 1000 filas y guardarlos en la carpeta indicada
import os

# Leer el archivo completo
a_exportar_csv = pd.read_csv('a_exportar.csv')

# Crear la carpeta si no existe
output_dir = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar'
os.makedirs(output_dir, exist_ok=True)

# Guardar en lotes de 1000
batch_size = 1000
for i in range(0, len(a_exportar_csv), batch_size):
    batch = a_exportar_csv.iloc[i:i+batch_size]
    batch_file = os.path.join(output_dir, f'a_importar_{i//batch_size + 1}.csv')
    batch.to_csv(batch_file, index=False)
    print(f'Guardado: {batch_file}')
# Out:
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_1.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_2.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_3.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_4.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_5.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_6.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_7.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_8.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_9.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_10.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_11.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_12.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_13.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_14.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_15.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_16.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_17.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_18.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_19.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_20.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_21.csv
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_22.csv

# %%
# Crear un nuevo CSV con todos los de 'a_exportar.csv' menos el primer batch de 'a importar'
import pandas as pd
import os

# Leer el archivo completo
a_exportar_csv = pd.read_csv('a_exportar.csv')

# Definir el tamaño del batch y la carpeta de salida
batch_size = 1000
output_dir = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar'

# Excluir las primeras 1000 filas
resto = a_exportar_csv.iloc[batch_size:]

# Guardar el nuevo archivo
resto_file = os.path.join(output_dir, 'a_importar_resto.csv')
resto.to_csv(resto_file, index=False)
print(f'Guardado: {resto_file}')
# Out:
# Guardado: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/a importar/a_importar_resto.csv

# %%
# Leer las reglas desde Odoo, tomar la última y mostrar todos los campos (con debug)
import os
import xmlrpc.client
from dotenv import load_dotenv
dotenv_path = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/odoo.env'
print('Cargando variables de entorno desde:', dotenv_path)
load_dotenv(dotenv_path)
ODOO_URL = os.getenv('ODOO_URL')
ODOO_DB = os.getenv('ODOO_DB')
ODOO_USER = os.getenv('ODOO_USERNAME')
ODOO_PASSWORD = os.getenv('ODOO_PASSWORD')
print('ODOO_URL:', ODOO_URL)
print('ODOO_DB:', ODOO_DB)
print('ODOO_USER:', ODOO_USER)
print('ODOO_PASSWORD:', '***' if ODOO_PASSWORD else None)
if not all([ODOO_URL, ODOO_DB, ODOO_USER, ODOO_PASSWORD]):
    raise ValueError('Faltan variables de entorno para la conexión a Odoo')
try:
    common = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/common')
    uid = common.authenticate(ODOO_DB, ODOO_USER, ODOO_PASSWORD, {})
    print('UID:', uid)
    if not uid:
        raise ValueError('No se pudo autenticar en Odoo. Verifica usuario y contraseña.')
    models = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/object')
    orderpoint_ids = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.warehouse.orderpoint', 'search', [[]])
    print('Cantidad de reglas encontradas:', len(orderpoint_ids))
    if not orderpoint_ids:
        raise ValueError('No se encontraron reglas en Odoo')
    orderpoints = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.warehouse.orderpoint', 'read', [orderpoint_ids[-1]])
    ultima_regla = orderpoints[-1]
    print('Campos de la última regla creada en Odoo:')
    for k, v in ultima_regla.items():
        print(f'{k}: {v}')
    ultima_regla
except Exception as e:
    print('Error al conectar o consultar Odoo:', e)
    raise
# Out:
# Cargando variables de entorno desde: /Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/odoo.env
# ODOO_URL: https://train-pldistribucion-05-09-1.adhoc.ar
# ODOO_DB: odoo
# ODOO_USER: matiasblanch@performance-lube.com
# ODOO_PASSWORD: ***
# UID: 6
# Cantidad de reglas encontradas: 22789
# Campos de la última regla creada en Odoo:
# id: 526
# smart_search: False
# message_is_follower: False
# message_follower_ids: []
# message_partner_ids: []
# message_ids: [743642]
# has_message: True
# message_needaction: False
# message_needaction_counter: 0
# message_has_error: False
# message_has_error_counter: 0
# message_attachment_count: 0
# rating_ids: []
# website_message_ids: []
# message_has_sms_error: False
# name: Reporte de reabastecimiento
# trigger: manual
# active: True
# snoozed_until: False
# warehouse_id: [9, 'Sucursal']
# location_id: [64, 'sucu/Existencias']
# product_tmpl_id: [23125, '[107796] YPF ELAION MOTO 4T SINTETICO 10W50 - 1L']
# product_id: [14871, '[107796] YPF ELAION MOTO 4T SINTETICO 10W50 - 1L']
# product_category_id: [260, 'ACEITE DE MOTOR (466110)']
# product_uom: [1, 'Units']
# product_uom_name: Units
# product_min_qty: 0.0
# product_max_qty: 0.0
# qty_multiple: 0.0
# group_id: False
# company_id: [2, 'PERFORMANCE LUBE DE GRUPO VLANTE SRL']
# allowed_location_ids: [2, 1, 3, 63, 64, 67]
# rule_ids: [17]
# lead_days_date: 2025-09-13
# route_id: [8, 'Buy']
# qty_on_hand: -2.0
# qty_forecast: -2.0
# qty_to_order: 2.0
# qty_to_order_computed: 2.0
# qty_to_order_manual: 0.0
# days_to_order: 0.0
# visibility_days: 0.0
# unwanted_replenish: False
# display_name: Reporte de reabastecimiento
# create_uid: [1, 'OdooBot']
# create_date: 2025-07-11 15:37:14
# write_uid: [6, 'Matias Ezequiel Blanch']
# write_date: 2025-07-11 15:37:14
# show_bom: False
# bom_id: False
# manufacturing_visibility_days: 0.0
# show_supplier: True
# supplier_id: [12114, 'GUAZZARONI GRECO S.A.']
# vendor_id: [9542, 'GUAZZARONI GRECO S.A.']
# purchase_visibility_days: 0.0
# product_supplier_id: [9542, 'GUAZZARONI GRECO S.A.']
# active_product: True
# rotation_stdev: 0.0
# warehouse_rotation_stdev: 0.0
# rotation: 0.0
# warehouse_rotation: 0.0
# reviewed: False

# %% [markdown]
# # Importante: para ver los ids de rutas y poder setearlos

# %%
# Mostrar todos los route_ids y sus nombres del modelo stock.route en Odoo
import os
import xmlrpc.client
from dotenv import load_dotenv
dotenv_path = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/odoo.env'
load_dotenv(dotenv_path)
ODOO_URL = os.getenv('ODOO_URL')
ODOO_DB = os.getenv('ODOO_DB')
ODOO_USER = os.getenv('ODOO_USERNAME')
ODOO_PASSWORD = os.getenv('ODOO_PASSWORD')
if not all([ODOO_URL, ODOO_DB, ODOO_USER, ODOO_PASSWORD]):
    raise ValueError('Faltan variables de entorno para la conexión a Odoo')
common = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(ODOO_DB, ODOO_USER, ODOO_PASSWORD, {})
if not uid:
    raise ValueError('No se pudo autenticar en Odoo. Verifica usuario y contraseña.')
models = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/object')
route_ids = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.route', 'search', [[]])
routes = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.route', 'read', [route_ids], {'fields': ['id', 'name', 'active']})
print('Todos los routes (id, name, active):')
for route in routes:
    print(route)
routes
# Out:
# Todos los routes (id, name, active):
# {'id': 13, 'name': 'Sucursal: suministrar producto de VLANTE 2', 'active': True}
# {'id': 18, 'name': 'VLANTE 2 (copia): suministrar producto de Sucursal', 'active': True}
# {'id': 29, 'name': 'Sucursal: Reabastecimiento Automático desde VLANTE 2 para ML (1 paso)', 'active': True}
# {'id': 8, 'name': 'Buy', 'active': True}
# {'id': 1, 'name': 'Replenish on Order (MTO)', 'active': True}
# {'id': 10, 'name': 'Sucursal: Recibir en 1 paso (existencias)', 'active': True}
# {'id': 14, 'name': 'VLANTE 2: suministrar producto de Sucursal', 'active': True}
# {'id': 5, 'name': 'VLANTE 2: Recibir en 1 paso (existencias)', 'active': True}
# {'id': 11, 'name': 'Sucursal: Entregar en 2 pasos (empaquetado + envío)', 'active': True}
# {'id': 6, 'name': 'VLANTE 2: Entregar en 2 pasos (empaquetado + envío)', 'active': True}
# {'id': 22, 'name': 'Manufacture', 'active': True}
# {'id': 15, 'name': 'NO USAR!!!!: Recibir en 1 paso (existencias)', 'active': True}
# {'id': 16, 'name': 'NO USAR!!!!: Entregar en 2 pasos (empaquetado + envío)', 'active': True}
# [{'id': 13,
#   'name': 'Sucursal: suministrar producto de VLANTE 2',
#   'active': True},
#  {'id': 18,
#   'name': 'VLANTE 2 (copia): suministrar producto de Sucursal',
#   'active': True},
#  {'id': 29,
#   'name': 'Sucursal: Reabastecimiento Automático desde VLANTE 2 para ML (1 paso)',
#   'active': True},
#  {'id': 8, 'name': 'Buy', 'active': True},
#  {'id': 1, 'name': 'Replenish on Order (MTO)', 'active': True},
#  {'id': 10,
#   'name': 'Sucursal: Recibir en 1 paso (existencias)',
#   'active': True},
#  {'id': 14,
#   'name': 'VLANTE 2: suministrar producto de Sucursal',
#   'active': True},
#  {'id': 5,
#   'name': 'VLANTE 2: Recibir en 1 paso (existencias)',
#   'active': True},
#  {'id': 11,
#   'name': 'Sucursal: Entregar en 2 pasos (empaquetado + envío)',
#   'active': True},
#  {'id': 6,
#   'name': 'VLANTE 2: Entregar en 2 pasos (empaquetado + envío)',
#   'active': True},
#  {'id': 22, 'name': 'Manufacture', 'active': True},
#  {'id': 15,
#   'name': 'NO USAR!!!!: Recibir en 1 paso (existencias)',
#   'active': True},
#  {'id': 16,
#   'name': 'NO USAR!!!!: Entregar en 2 pasos (empaquetado + envío)',
#   'active': True}]

# %%
# Mostrar todos los location_ids y sus nombres del modelo stock.location en Odoo
import os
import xmlrpc.client
from dotenv import load_dotenv
dotenv_path = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/odoo.env'
load_dotenv(dotenv_path)
ODOO_URL = os.getenv('ODOO_URL')
ODOO_DB = os.getenv('ODOO_DB')
ODOO_USER = os.getenv('ODOO_USERNAME')
ODOO_PASSWORD = os.getenv('ODOO_PASSWORD')
if not all([ODOO_URL, ODOO_DB, ODOO_USER, ODOO_PASSWORD]):
    raise ValueError('Faltan variables de entorno para la conexión a Odoo')
common = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(ODOO_DB, ODOO_USER, ODOO_PASSWORD, {})
if not uid:
    raise ValueError('No se pudo autenticar en Odoo. Verifica usuario y contraseña.')
models = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/object')
location_ids = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.location', 'search', [[]])
locations = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.location', 'read', [location_ids], {'fields': ['id', 'name', 'complete_name', 'usage', 'active']})
print('Todos los locations (id, name, complete_name, usage, active):')
for loc in locations:
    print(loc)
locations
# Out:
# Todos los locations (id, name, complete_name, usage, active):
# {'id': 70, 'name': 'NOUSE', 'complete_name': 'NOUSE', 'usage': 'view', 'active': True}
# {'id': 71, 'name': 'Existencias', 'complete_name': 'NOUSE/Existencias', 'usage': 'internal', 'active': True}
# {'id': 74, 'name': 'Salida', 'complete_name': 'NOUSE/Salida', 'usage': 'internal', 'active': True}
# {'id': 2, 'name': 'Partners', 'complete_name': 'Partners', 'usage': 'view', 'active': True}
# {'id': 5, 'name': 'Customers', 'complete_name': 'Partners/Customers', 'usage': 'customer', 'active': True}
# {'id': 4, 'name': 'Vendors', 'complete_name': 'Partners/Vendors', 'usage': 'supplier', 'active': True}
# {'id': 1, 'name': 'Physical Locations', 'complete_name': 'Physical Locations', 'usage': 'view', 'active': True}
# {'id': 17, 'name': 'Traslado entre almacenes', 'complete_name': 'Physical Locations/Traslado entre almacenes', 'usage': 'transit', 'active': True}
# {'id': 21, 'name': 'VLANT', 'complete_name': 'VLANT', 'usage': 'view', 'active': True}
# {'id': 22, 'name': 'Existencias', 'complete_name': 'VLANT/Existencias', 'usage': 'internal', 'active': True}
# {'id': 69, 'name': 'RACK 1', 'complete_name': 'VLANT/Existencias/RACK 1', 'usage': 'internal', 'active': True}
# {'id': 25, 'name': 'Salida', 'complete_name': 'VLANT/Salida', 'usage': 'internal', 'active': True}
# {'id': 3, 'name': 'Virtual Locations', 'complete_name': 'Virtual Locations', 'usage': 'view', 'active': True}
# {'id': 6, 'name': 'Inter-company transit', 'complete_name': 'Virtual Locations/Inter-company transit', 'usage': 'transit', 'active': True}
# {'id': 14, 'name': 'Inventory adjustment', 'complete_name': 'Virtual Locations/Inventory adjustment', 'usage': 'inventory', 'active': True}
# {'id': 18, 'name': 'Inventory adjustment', 'complete_name': 'Virtual Locations/Inventory adjustment', 'usage': 'inventory', 'active': True}
# {'id': 77, 'name': 'Inventory adjustment', 'complete_name': 'Virtual Locations/Inventory adjustment', 'usage': 'inventory', 'active': True}
# {'id': 15, 'name': 'Production', 'complete_name': 'Virtual Locations/Production', 'usage': 'production', 'active': True}
# {'id': 19, 'name': 'Production', 'complete_name': 'Virtual Locations/Production', 'usage': 'production', 'active': True}
# {'id': 78, 'name': 'Production', 'complete_name': 'Virtual Locations/Production', 'usage': 'production', 'active': True}
# {'id': 16, 'name': 'Scrap', 'complete_name': 'Virtual Locations/Scrap', 'usage': 'inventory', 'active': True}
# {'id': 20, 'name': 'Scrap', 'complete_name': 'Virtual Locations/Scrap', 'usage': 'inventory', 'active': True}
# {'id': 79, 'name': 'Scrap', 'complete_name': 'Virtual Locations/Scrap', 'usage': 'inventory', 'active': True}
# {'id': 63, 'name': 'sucu', 'complete_name': 'sucu', 'usage': 'view', 'active': True}
# {'id': 64, 'name': 'Existencias', 'complete_name': 'sucu/Existencias', 'usage': 'internal', 'active': True}
# {'id': 67, 'name': 'Salida', 'complete_name': 'sucu/Salida', 'usage': 'internal', 'active': True}
# [{'id': 70,
#   'name': 'NOUSE',
#   'complete_name': 'NOUSE',
#   'usage': 'view',
#   'active': True},
#  {'id': 71,
#   'name': 'Existencias',
#   'complete_name': 'NOUSE/Existencias',
#   'usage': 'internal',
#   'active': True},
#  {'id': 74,
#   'name': 'Salida',
#   'complete_name': 'NOUSE/Salida',
#   'usage': 'internal',
#   'active': True},
#  {'id': 2,
#   'name': 'Partners',
#   'complete_name': 'Partners',
#   'usage': 'view',
#   'active': True},
#  {'id': 5,
#   'name': 'Customers',
#   'complete_name': 'Partners/Customers',
#   'usage': 'customer',
#   'active': True},
#  {'id': 4,
#   'name': 'Vendors',
#   'complete_name': 'Partners/Vendors',
#   'usage': 'supplier',
#   'active': True},
#  {'id': 1,
#   'name': 'Physical Locations',
#   'complete_name': 'Physical Locations',
#   'usage': 'view',
#   'active': True},
#  {'id': 17,
#   'name': 'Traslado entre almacenes',
#   'complete_name': 'Physical Locations/Traslado entre almacenes',
#   'usage': 'transit',
#   'active': True},
#  {'id': 21,
#   'name': 'VLANT',
#   'complete_name': 'VLANT',
#   'usage': 'view',
#   'active': True},
#  {'id': 22,
#   'name': 'Existencias',
#   'complete_name': 'VLANT/Existencias',
#   'usage': 'internal',
#   'active': True},
#  {'id': 69,
#   'name': 'RACK 1',
#   'complete_name': 'VLANT/Existencias/RACK 1',
#   'usage': 'internal',
#   'active': True},
#  {'id': 25,
#   'name': 'Salida',
#   'complete_name': 'VLANT/Salida',
#   'usage': 'internal',
#   'active': True},
#  {'id': 3,
#   'name': 'Virtual Locations',
#   'complete_name': 'Virtual Locations',
#   'usage': 'view',
#   'active': True},
#  {'id': 6,
#   'name': 'Inter-company transit',
#   'complete_name': 'Virtual Locations/Inter-company transit',
#   'usage': 'transit',
#   'active': True},
#  {'id': 14,
#   'name': 'Inventory adjustment',
#   'complete_name': 'Virtual Locations/Inventory adjustment',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 18,
#   'name': 'Inventory adjustment',
#   'complete_name': 'Virtual Locations/Inventory adjustment',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 77,
#   'name': 'Inventory adjustment',
#   'complete_name': 'Virtual Locations/Inventory adjustment',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 15,
#   'name': 'Production',
#   'complete_name': 'Virtual Locations/Production',
#   'usage': 'production',
#   'active': True},
#  {'id': 19,
#   'name': 'Production',
#   'complete_name': 'Virtual Locations/Production',
#   'usage': 'production',
#   'active': True},
#  {'id': 78,
#   'name': 'Production',
#   'complete_name': 'Virtual Locations/Production',
#   'usage': 'production',
#   'active': True},
#  {'id': 16,
#   'name': 'Scrap',
#   'complete_name': 'Virtual Locations/Scrap',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 20,
#   'name': 'Scrap',
#   'complete_name': 'Virtual Locations/Scrap',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 79,
#   'name': 'Scrap',
#   'complete_name': 'Virtual Locations/Scrap',
#   'usage': 'inventory',
#   'active': True},
#  {'id': 63,
#   'name': 'sucu',
#   'complete_name': 'sucu',
#   'usage': 'view',
#   'active': True},
#  {'id': 64,
#   'name': 'Existencias',
#   'complete_name': 'sucu/Existencias',
#   'usage': 'internal',
#   'active': True},
#  {'id': 67,
#   'name': 'Salida',
#   'complete_name': 'sucu/Salida',
#   'usage': 'internal',
#   'active': True}]

# %%
# Imprimir los campos warehouse_id de dos reglas con distinto location_id
import os
import xmlrpc.client
from dotenv import load_dotenv
dotenv_path = '/Users/pablo/Documents/Saucotec/Performance - Stage 2/reglas_reabastecimiento/odoo.env'
load_dotenv(dotenv_path)
ODOO_URL = os.getenv('ODOO_URL')
ODOO_DB = os.getenv('ODOO_DB')
ODOO_USER = os.getenv('ODOO_USERNAME')
ODOO_PASSWORD = os.getenv('ODOO_PASSWORD')
if not all([ODOO_URL, ODOO_DB, ODOO_USER, ODOO_PASSWORD]):
    raise ValueError('Faltan variables de entorno para la conexión a Odoo')
common = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/common')
uid = common.authenticate(ODOO_DB, ODOO_USER, ODOO_PASSWORD, {})
if not uid:
    raise ValueError('No se pudo autenticar en Odoo. Verifica usuario y contraseña.')
models = xmlrpc.client.ServerProxy(f'{ODOO_URL}/xmlrpc/2/object')
orderpoint_ids = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.warehouse.orderpoint', 'search', [[]])
if not orderpoint_ids:
    raise ValueError('No se encontraron reglas en Odoo')
orderpoints = models.execute_kw(ODOO_DB, uid, ODOO_PASSWORD, 'stock.warehouse.orderpoint', 'read', [orderpoint_ids], {'fields': ['id', 'warehouse_id', 'location_id']})
vistos = {}
encontrados = []
for op in orderpoints:
    loc = op.get('location_id')
    if loc and loc[0] not in vistos:
        vistos[loc[0]] = op
        if len(vistos) == 2:
            break
if len(vistos) < 2:
    print('No se encontraron dos reglas con distinto location_id.')
else:
    print('Campos warehouse_id de dos reglas con distinto location_id:')
    for op in vistos.values():
        print('orderpoint_id:', op['id'], '| warehouse_id:', op['warehouse_id'], '| location_id:', op['location_id'])
